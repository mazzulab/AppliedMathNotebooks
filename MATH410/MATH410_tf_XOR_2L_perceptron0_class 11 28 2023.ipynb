# %% [markdown]
# # Tensorflow tutorial with Keras
#
# # Example 1: Build a 2-layer perceptron with fixed weights
#
# - Initialize a 2-layer network with sigmoid activation functions.
# - Set weights and biases by hand with values that solves the XOR problem.
# - Visualize the network and test classification.
#
# ## Activity rule and cost function
# Activity:
# $$
# f(h)={1\over 1+e^{-h}}\ , \,\,h^\mu=\sum_{i=1}^Nw_ix_i^\mu+b
# $$
#
# Log-likelihood function:
# $$
# G(t^\mu|x^\mu_i,w_i)=-\sum_{\mu=1}^p\left[t^\mu\ln f(h^\mu)+(1-t^\mu)\ln(1- f(h^\mu))\right]
# $$

# %%
import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
from tensorflow.keras.regularizers import l2

# %% [markdown]
# # Example 1
#
# XOR problem with a 2-layer perceptron

# %%
n_features=2 # dimension of input space
Nhidden=2 # number of hidden units
# define the model
model=Sequential()
#hidden layer
# activation could be sigmoid or relu
# kernel_initializer='he_normal' means the weights are initialized as gaussian distr. with mean 0 and variance 1/N
model.add(Dense(Nhidden,activation='sigmoid',kernel_initializer='he_normal',input_shape=(n_features,)))
#output layer
model.add(Dense(1,activation='sigmoid',kernel_initializer='he_normal'))
# set the weights by hand
w1=np.ones((n_features,Nhidden)) # rows=inputs, cols=hidden units
b1=np.zeros((Nhidden,)) # bias for the hidden layer units
w2=np.zeros((Nhidden,1)) # rows=hidden units, cols=output
b2=np.zeros((1,)) # bias for the output
# assign the values of the weights
b1[0]=1; b1[1]=-1
w2[0]=1; w2[1]=-1
b2[0]=-0.25

# set the weights
model.set_weights([w1,b1,w2,b2])

# compile the model
model.compile(loss='binary_crossentropy',metrics='accuracy')


print(model.summary())
print('show trainable parameters')
print(model.trainable_variables)

weights=model.get_weights()
print('print weights')
print(weights)

# check it solves the XOR problem
x1=np.array([[-1,-1],[-1,+1],[+1,-1],[+1,+1]]) # input patterns
z1=np.array([0,1,1,0])
loss,acc=model.evaluate(x1,z1,verbose=1)
print('test accuracy: %.3f' % acc)

plot_model(model,show_shapes=True,rankdir='LR',to_file='model.png')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 6
#
#  dense_1 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________
# None
# show trainable parameters
# [<tf.Variable 'dense/kernel:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(2,) dtype=float32, numpy=array([ 1., -1.], dtype=float32)>, <tf.Variable 'dense_1/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[ 1.],
#        [-1.]], dtype=float32)>, <tf.Variable 'dense_1/bias:0' shape=(1,) dtype=float32, numpy=array([-0.25], dtype=float32)>]
# print weights
# [array([[1., 1.],
#        [1., 1.]], dtype=float32), array([ 1., -1.], dtype=float32), array([[ 1.],
#        [-1.]], dtype=float32), array([-0.25], dtype=float32)]
# 1/1 [==============================] - 0s 290ms/step - loss: 0.6359 - accuracy: 1.0000
# test accuracy: 1.000

# %%
def generate_patterns(spread,N=2,p1=100,p2=100,option='separable',plot=False):

    # generate targets
    t=np.ones((p1+p2))# targets
    t[p1:]=0 # t2=0 targets
    x=np.zeros((p1+p2,N))
    
    # generate inputs
    if option=='separable':
        # separable targets
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
    elif option=='nonseparable':
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[0:int(p1/2),0:N]=-x[0:int(p1/2),0:N]
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
        x[int(p1+p2/2):(p1+p2),0]=-x[int(p1+p2/2):(p1+p2),0]; x[p1:int(p1+p2/2),1]=-x[p1:int(p1+p2/2),1]
    elif option=='weird':
        x[0:p1,0:N]=1+spread*np.random.randn(N*p1).reshape(p1,N)
        x[0:int(p1/2),0:N]=-x[0:int(p1/2),0:N]+1.5
        x[p1:p1+p2,0:N]=-1+spread*np.random.randn(N*p2).reshape(p2,N)
        x[int(p1+p2/2):(p1+p2),0]=-x[int(p1+p2/2):(p1+p2),0]; x[p1:int(p1+p2/2),1]=-x[p1:int(p1+p2/2),1]+1
        t=np.ones((p1+p2))# targets
        t[0:int(p1/2)]=0; t[p1:int(p1+p2/2)]=0

    # make a figure
    if plot == True:
        fig,ax=plt.subplots()
        plt.title('Linearly {} Patterns with Spread of {}'.format(option,spread))
        size=100
        # scatterplot
        ax.scatter(x[t==1,0],x[t==1,1],s=size,color='red',alpha=0.25,label='+1')
        ax.scatter(x[t==0,0],x[t==0,1],s=size,color='blue',alpha=0.25,label='0')
        ax.set_xlabel("x1"); ax.set_ylabel("x2")
        ax.legend(loc='lower right')
        ax.axis('equal')  
    return x,t

# %% [markdown]
# # Example 2: Train a single layer perceptron
#
# Workflow:
# - Generate input patterns.
# - Split them into training and test set.
# - Define model: Initialize a 1-layer network (perceptron) with sigmoid activation functions.
# - Compile the model: Set optimization, loss function, and metrics for training.
# - Train network using SGD and adam.
# - Test network performance.
# - Visualize the network training history.
#
# Plot training history: accuracy and loss on training and test sets

# %%
# generate patterns
X,y=generate_patterns(spread=0.5,N=2,p1=1000,p2=1000,option='nonseparable',plot=True)
# split into training and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33)

print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# dimensions of input features
n_patterns,n_features=X.shape
# Out:
# (1340, 2) (660, 2) (1340,) (660,)

# %%
# define model
model=Sequential()
model.add(Dense(1,activation='sigmoid',kernel_initializer='he_normal',input_shape=(n_features,)))

# 'he_normal" draws weights from a gaussian with mean zero and standard deviation sqrt(2)/fan_in, where 
# fan_in is the number of input units
# kernel_regularizer=l2(alpha) is the weight decay with quadratic loss function with weight alpha
# add weight decay
# docs: https://machinelearningmastery.com/how-to-reduce-overfitting-in-deep-learning-with-weight-regularization/

# choose optimizer


# compile model
model.compile(optimizer='SGD',loss='binary_crossentropy',metrics=['accuracy'])
print(model.summary())

# early stopping
# split training set into smaller training set and validation set
X_train0,X_val,y_train0,y_val=train_test_split(X_train,y_train,test_size=0.33)

# define the early stopping with a callback
cb=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',mode='max',patience=30)
# fit the model
history=model.fit(X_train0,y_train0,epochs=100,validation_data=(X_val,y_val),batch_size=32,callbacks=[cb],verbose=1)
# evaluate the model
print('test model')
print(model.trainable_variables)

loss,acc=model.evaluate(X_test,y_test,verbose=1)

print('test accuracy: %.3f' % acc)
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 1)                 3
#
# =================================================================
# Total params: 3
# Trainable params: 3
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 29/29 [==============================] - 1s 24ms/step - loss: 1.0085 - accuracy: 0.5139 - val_loss: 0.9912 - val_accuracy: 0.4989
# Epoch 2/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9748 - accuracy: 0.5139 - val_loss: 0.9560 - val_accuracy: 0.4989
# Epoch 3/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9409 - accuracy: 0.5128 - val_loss: 0.9239 - val_accuracy: 0.4989
# Epoch 4/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.9101 - accuracy: 0.5117 - val_loss: 0.8975 - val_accuracy: 0.4989
# Epoch 5/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.8851 - accuracy: 0.5106 - val_loss: 0.8699 - val_accuracy: 0.4989
# Epoch 6/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.8596 - accuracy: 0.5117 - val_loss: 0.8460 - val_accuracy: 0.4989
# Epoch 7/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.8373 - accuracy: 0.5117 - val_loss: 0.8252 - val_accuracy: 0.4989
# Epoch 8/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.8177 - accuracy: 0.5117 - val_loss: 0.8083 - val_accuracy: 0.4989
# Epoch 9/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.8019 - accuracy: 0.5106 - val_loss: 0.7902 - val_accuracy: 0.4989
# Epoch 10/100
# 29/29 [==============================] - 0s 11ms/step - loss: 0.7852 - accuracy: 0.5117 - val_loss: 0.7774 - val_accuracy: 0.5011
# Epoch 11/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7731 - accuracy: 0.5117 - val_loss: 0.7659 - val_accuracy: 0.5011
# Epoch 12/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7624 - accuracy: 0.5117 - val_loss: 0.7529 - val_accuracy: 0.5034
# Epoch 13/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7501 - accuracy: 0.5117 - val_loss: 0.7446 - val_accuracy: 0.5011
# Epoch 14/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7424 - accuracy: 0.5117 - val_loss: 0.7360 - val_accuracy: 0.5011
# Epoch 15/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7344 - accuracy: 0.5117 - val_loss: 0.7301 - val_accuracy: 0.5011
# Epoch 16/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7290 - accuracy: 0.5117 - val_loss: 0.7238 - val_accuracy: 0.5011
# Epoch 17/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7230 - accuracy: 0.5128 - val_loss: 0.7195 - val_accuracy: 0.5011
# Epoch 18/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7187 - accuracy: 0.5139 - val_loss: 0.7152 - val_accuracy: 0.5056
# Epoch 19/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7145 - accuracy: 0.5139 - val_loss: 0.7119 - val_accuracy: 0.5079
# Epoch 20/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7115 - accuracy: 0.5128 - val_loss: 0.7080 - val_accuracy: 0.5056
# Epoch 21/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7079 - accuracy: 0.5162 - val_loss: 0.7061 - val_accuracy: 0.5056
# Epoch 22/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7061 - accuracy: 0.5139 - val_loss: 0.7035 - val_accuracy: 0.5056
# Epoch 23/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7038 - accuracy: 0.5173 - val_loss: 0.7015 - val_accuracy: 0.5056
# Epoch 24/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7018 - accuracy: 0.5151 - val_loss: 0.7005 - val_accuracy: 0.5124
# Epoch 25/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.7007 - accuracy: 0.5117 - val_loss: 0.6997 - val_accuracy: 0.5102
# Epoch 26/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6996 - accuracy: 0.5117 - val_loss: 0.6989 - val_accuracy: 0.5102
# Epoch 27/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6987 - accuracy: 0.5117 - val_loss: 0.6975 - val_accuracy: 0.5124
# Epoch 28/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6975 - accuracy: 0.5117 - val_loss: 0.6971 - val_accuracy: 0.5102
# Epoch 29/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6969 - accuracy: 0.5117 - val_loss: 0.6965 - val_accuracy: 0.5124
# Epoch 30/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6960 - accuracy: 0.5128 - val_loss: 0.6960 - val_accuracy: 0.5147
# Epoch 31/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6957 - accuracy: 0.5139 - val_loss: 0.6957 - val_accuracy: 0.5102
# Epoch 32/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6955 - accuracy: 0.5162 - val_loss: 0.6957 - val_accuracy: 0.5124
# Epoch 33/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6953 - accuracy: 0.5128 - val_loss: 0.6950 - val_accuracy: 0.5124
# Epoch 34/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6948 - accuracy: 0.5117 - val_loss: 0.6948 - val_accuracy: 0.5102
# Epoch 35/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6947 - accuracy: 0.5162 - val_loss: 0.6947 - val_accuracy: 0.5102
# Epoch 36/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6947 - accuracy: 0.5162 - val_loss: 0.6941 - val_accuracy: 0.5147
# Epoch 37/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6943 - accuracy: 0.5151 - val_loss: 0.6940 - val_accuracy: 0.5237
# Epoch 38/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6938 - accuracy: 0.5195 - val_loss: 0.6939 - val_accuracy: 0.5350
# Epoch 39/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6935 - accuracy: 0.5362 - val_loss: 0.6936 - val_accuracy: 0.5350
# Epoch 40/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6935 - accuracy: 0.5362 - val_loss: 0.6938 - val_accuracy: 0.5350
# Epoch 41/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6935 - accuracy: 0.5362 - val_loss: 0.6937 - val_accuracy: 0.5621
# Epoch 42/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5518 - val_loss: 0.6936 - val_accuracy: 0.5530
# Epoch 43/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6934 - accuracy: 0.5619 - val_loss: 0.6937 - val_accuracy: 0.5576
# Epoch 44/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5507 - val_loss: 0.6936 - val_accuracy: 0.5395
# Epoch 45/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5541 - val_loss: 0.6938 - val_accuracy: 0.5305
# Epoch 46/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5396 - val_loss: 0.6939 - val_accuracy: 0.5237
# Epoch 47/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5318 - val_loss: 0.6939 - val_accuracy: 0.5485
# Epoch 48/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5686 - val_loss: 0.6938 - val_accuracy: 0.5508
# Epoch 49/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6932 - accuracy: 0.5608 - val_loss: 0.6937 - val_accuracy: 0.5576
# Epoch 50/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6933 - accuracy: 0.5541 - val_loss: 0.6935 - val_accuracy: 0.5508
# Epoch 51/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5541 - val_loss: 0.6937 - val_accuracy: 0.5372
# Epoch 52/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5496 - val_loss: 0.6936 - val_accuracy: 0.5237
# Epoch 53/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5396 - val_loss: 0.6935 - val_accuracy: 0.5147
# Epoch 54/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5295 - val_loss: 0.6937 - val_accuracy: 0.4921
# Epoch 55/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5039 - val_loss: 0.6939 - val_accuracy: 0.4763
# Epoch 56/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5006 - val_loss: 0.6942 - val_accuracy: 0.4447
# Epoch 57/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.4638 - val_loss: 0.6942 - val_accuracy: 0.4740
# Epoch 58/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.4983 - val_loss: 0.6940 - val_accuracy: 0.4447
# Epoch 59/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.4615 - val_loss: 0.6943 - val_accuracy: 0.4357
# Epoch 60/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.4571 - val_loss: 0.6940 - val_accuracy: 0.4605
# Epoch 61/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.4816 - val_loss: 0.6941 - val_accuracy: 0.5056
# Epoch 62/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5128 - val_loss: 0.6942 - val_accuracy: 0.5372
# Epoch 63/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5719 - val_loss: 0.6941 - val_accuracy: 0.5666
# Epoch 64/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6031 - val_loss: 0.6943 - val_accuracy: 0.5305
# Epoch 65/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5730 - val_loss: 0.6944 - val_accuracy: 0.5147
# Epoch 66/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5251 - val_loss: 0.6946 - val_accuracy: 0.5395
# Epoch 67/100
# 29/29 [==============================] - 0s 9ms/step - loss: 0.6930 - accuracy: 0.5574 - val_loss: 0.6950 - val_accuracy: 0.5372
# Epoch 68/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5641 - val_loss: 0.6951 - val_accuracy: 0.5260
# Epoch 69/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5507 - val_loss: 0.6948 - val_accuracy: 0.5440
# Epoch 70/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5853 - val_loss: 0.6945 - val_accuracy: 0.5801
# Epoch 71/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6931 - accuracy: 0.5886 - val_loss: 0.6947 - val_accuracy: 0.5937
# Epoch 72/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6221 - val_loss: 0.6944 - val_accuracy: 0.6163
# Epoch 73/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6611 - val_loss: 0.6941 - val_accuracy: 0.6433
# Epoch 74/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6789 - val_loss: 0.6938 - val_accuracy: 0.6366
# Epoch 75/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6678 - val_loss: 0.6940 - val_accuracy: 0.6343
# Epoch 76/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6778 - val_loss: 0.6939 - val_accuracy: 0.6208
# Epoch 77/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6433 - val_loss: 0.6938 - val_accuracy: 0.6072
# Epoch 78/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6499 - val_loss: 0.6940 - val_accuracy: 0.6050
# Epoch 79/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6410 - val_loss: 0.6940 - val_accuracy: 0.5892
# Epoch 80/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6276 - val_loss: 0.6942 - val_accuracy: 0.5530
# Epoch 81/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5563 - val_loss: 0.6939 - val_accuracy: 0.5395
# Epoch 82/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5596 - val_loss: 0.6941 - val_accuracy: 0.5440
# Epoch 83/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5897 - val_loss: 0.6942 - val_accuracy: 0.5260
# Epoch 84/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5563 - val_loss: 0.6942 - val_accuracy: 0.5056
# Epoch 85/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5318 - val_loss: 0.6944 - val_accuracy: 0.4876
# Epoch 86/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5117 - val_loss: 0.6943 - val_accuracy: 0.5056
# Epoch 87/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5351 - val_loss: 0.6944 - val_accuracy: 0.5372
# Epoch 88/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5619 - val_loss: 0.6941 - val_accuracy: 0.5192
# Epoch 89/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5563 - val_loss: 0.6939 - val_accuracy: 0.5508
# Epoch 90/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5708 - val_loss: 0.6941 - val_accuracy: 0.5169
# Epoch 91/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5507 - val_loss: 0.6940 - val_accuracy: 0.5576
# Epoch 92/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5842 - val_loss: 0.6942 - val_accuracy: 0.5711
# Epoch 93/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6165 - val_loss: 0.6942 - val_accuracy: 0.5372
# Epoch 94/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5797 - val_loss: 0.6946 - val_accuracy: 0.5282
# Epoch 95/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5574 - val_loss: 0.6943 - val_accuracy: 0.5553
# Epoch 96/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.5998 - val_loss: 0.6945 - val_accuracy: 0.5440
# Epoch 97/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.5719 - val_loss: 0.6942 - val_accuracy: 0.5982
# Epoch 98/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6930 - accuracy: 0.6366 - val_loss: 0.6941 - val_accuracy: 0.5643
# Epoch 99/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6031 - val_loss: 0.6938 - val_accuracy: 0.6072
# Epoch 100/100
# 29/29 [==============================] - 0s 10ms/step - loss: 0.6929 - accuracy: 0.6343 - val_loss: 0.6939 - val_accuracy: 0.6275
# test model
# [<tf.Variable 'dense_9/kernel:0' shape=(2, 1) dtype=float32, numpy=
# array([[ 0.0395852 ],
#        [-0.03316537]], dtype=float32)>, <tf.Variable 'dense_9/bias:0' shape=(1,) dtype=float32, numpy=array([0.023156], dtype=float32)>]
# 21/21 [==============================] - 0s 8ms/step - loss: 0.6950 - accuracy: 0.6258
# test accuracy: 0.626

# %%
print(history.history.keys())
# plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training history')
plt.xlabel('training epochs')
plt.ylabel('accuracy')
plt.legend(['Training','Val'],loc='upper left')
plt.show()

# plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training history')
plt.xlabel('training epochs')
plt.ylabel('loss')
plt.legend(['Training','Val'],loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Example 3: Train a two-layer perceptron
#
# Workflow:
# - Generate input patterns.
# - Split them into training and test set.
# - Define model: Initialize a 2-layer network with sigmoid activation functions.
# - Compile the model: Set optimization, loss function, and metrics for training.
# - Train network using SGD and adam.
# - Test network performance.
# - Visualize the network training history.

# %%
# generate patterns
X,y=generate_patterns(spread=0.2,N=2,p1=1000,p2=1000,option='nonseparable',plot=True)
# split into training and test sets
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33)
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# dimensions of input features
n_patterns,n_features=X.shape
# Out:
# (1340, 2) (660, 2) (1340,) (660,)

# %%
# define the model
alpha=0.1 # weight decay term
p_dropout=0.5 # fraction of weights set to zero at each training epoch
model=Sequential()
model.add(Dense(20,activation='relu',kernel_regularizer=l2(alpha),kernel_initializer='he_normal',input_shape=(n_features,)))
model.add(tf.keras.layers.Dropout(p_dropout))
model.add(Dense(20,activation='relu',kernel_regularizer=l2(alpha),kernel_initializer='he_normal'))
model.add(tf.keras.layers.Dropout(p_dropout))
model.add(Dense(1,activation='sigmoid',kernel_initializer='he_normal'))
model.add(tf.keras.layers.Dropout(0.2))

# compile
# adam optimizer
model.compile(optimizer='adam',loss='binary_crossentropy',metrics='accuracy')
# stochastic gradient descent optimizer
# model.compile(optimizer='SGD',loss='binary_crossentropy',metrics='accuracy')
print(model.summary())

# fit the model
X_train0,X_val,y_train0,y_val=train_test_split(X_train,y_train,test_size=0.33)

# define the early stopping with a callback
cb=tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',mode='max',patience=30)
# fit the model
history=model.fit(X_train0,y_train0,epochs=100,validation_data=(X_val,y_val),batch_size=5,callbacks=[cb],verbose=1)



# evaluate the model
print('test model')
print(model.trainable_variables)

print('test accuracy: %.3f' % acc)

# plot training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training history')
plt.ylabel('accuracy')
plt.xlabel('training epochs')
plt.legend(['Training','Validation'],loc='upper left')
plt.show()

# plot training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Training history')
plt.ylabel('loss')
plt.xlabel('training epochs')
plt.legend(['Training','Validation'],loc='upper left')
plt.show()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_27 (Dense)            (None, 20)                60
#
#  dropout_10 (Dropout)        (None, 20)                0
#
#  dense_28 (Dense)            (None, 20)                420
#
#  dropout_11 (Dropout)        (None, 20)                0
#
#  dense_29 (Dense)            (None, 1)                 21
#
#  dropout_12 (Dropout)        (None, 1)                 0
#
# =================================================================
# Total params: 501
# Trainable params: 501
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 180/180 [==============================] - 5s 22ms/step - loss: 8.6380 - accuracy: 0.6020 - val_loss: 5.1629 - val_accuracy: 0.6817
# Epoch 2/100
# 180/180 [==============================] - 3s 15ms/step - loss: 6.0006 - accuracy: 0.7536 - val_loss: 3.3865 - val_accuracy: 0.9729
# Epoch 3/100
# 180/180 [==============================] - 3s 15ms/step - loss: 4.1904 - accuracy: 0.8361 - val_loss: 2.4006 - val_accuracy: 1.0000
# Epoch 4/100
# 180/180 [==============================] - 3s 15ms/step - loss: 3.4636 - accuracy: 0.8439 - val_loss: 1.7833 - val_accuracy: 1.0000
# Epoch 5/100
# 180/180 [==============================] - 3s 15ms/step - loss: 2.8512 - accuracy: 0.8863 - val_loss: 1.3748 - val_accuracy: 1.0000
# Epoch 6/100
# 180/180 [==============================] - 3s 15ms/step - loss: 2.5219 - accuracy: 0.8963 - val_loss: 1.1173 - val_accuracy: 1.0000
# Epoch 7/100
# 180/180 [==============================] - 3s 15ms/step - loss: 2.2630 - accuracy: 0.9008 - val_loss: 0.9380 - val_accuracy: 1.0000
# Epoch 8/100
# 180/180 [==============================] - 3s 14ms/step - loss: 2.2483 - accuracy: 0.8941 - val_loss: 0.8191 - val_accuracy: 1.0000
# Epoch 9/100
# 180/180 [==============================] - 3s 14ms/step - loss: 2.0695 - accuracy: 0.8986 - val_loss: 0.7504 - val_accuracy: 0.9955
# Epoch 10/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.9966 - accuracy: 0.8986 - val_loss: 0.6870 - val_accuracy: 0.9977
# Epoch 11/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.8078 - accuracy: 0.9075 - val_loss: 0.6540 - val_accuracy: 0.9932
# Epoch 12/100
# 180/180 [==============================] - 3s 15ms/step - loss: 1.8506 - accuracy: 0.9019 - val_loss: 0.6299 - val_accuracy: 0.9910
# Epoch 13/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7770 - accuracy: 0.9052 - val_loss: 0.6041 - val_accuracy: 1.0000
# Epoch 14/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.9415 - accuracy: 0.8930 - val_loss: 0.5891 - val_accuracy: 0.9932
# Epoch 15/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7658 - accuracy: 0.9030 - val_loss: 0.5714 - val_accuracy: 0.9977
# Epoch 16/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7606 - accuracy: 0.9019 - val_loss: 0.5572 - val_accuracy: 0.9910
# Epoch 17/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7130 - accuracy: 0.9041 - val_loss: 0.5388 - val_accuracy: 0.9977
# Epoch 18/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.8740 - accuracy: 0.8930 - val_loss: 0.5351 - val_accuracy: 0.9955
# Epoch 19/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.6684 - accuracy: 0.9052 - val_loss: 0.5074 - val_accuracy: 1.0000
# Epoch 20/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7238 - accuracy: 0.9008 - val_loss: 0.4926 - val_accuracy: 1.0000
# Epoch 21/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.7310 - accuracy: 0.8997 - val_loss: 0.4905 - val_accuracy: 1.0000
# Epoch 22/100
# 180/180 [==============================] - 3s 15ms/step - loss: 1.7064 - accuracy: 0.9008 - val_loss: 0.4832 - val_accuracy: 1.0000
# Epoch 23/100
# 180/180 [==============================] - 3s 15ms/step - loss: 1.6694 - accuracy: 0.9030 - val_loss: 0.4904 - val_accuracy: 0.9910
# Epoch 24/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.6957 - accuracy: 0.9008 - val_loss: 0.4911 - val_accuracy: 0.9910
# Epoch 25/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.5191 - accuracy: 0.9119 - val_loss: 0.4774 - val_accuracy: 0.9932
# Epoch 26/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.9479 - accuracy: 0.8841 - val_loss: 0.4887 - val_accuracy: 0.9910
# Epoch 27/100
# 180/180 [==============================] - 3s 15ms/step - loss: 1.8222 - accuracy: 0.8919 - val_loss: 0.4691 - val_accuracy: 0.9932
# Epoch 28/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.6265 - accuracy: 0.9041 - val_loss: 0.4672 - val_accuracy: 0.9910
# Epoch 29/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.6267 - accuracy: 0.9041 - val_loss: 0.4826 - val_accuracy: 0.9910
# Epoch 30/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.5883 - accuracy: 0.9064 - val_loss: 0.4663 - val_accuracy: 0.9910
# Epoch 31/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.5851 - accuracy: 0.9064 - val_loss: 0.4675 - val_accuracy: 0.9910
# Epoch 32/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.6332 - accuracy: 0.9030 - val_loss: 0.4768 - val_accuracy: 0.9887
# Epoch 33/100
# 180/180 [==============================] - 3s 14ms/step - loss: 1.8038 - accuracy: 0.8919 - val_loss: 0.4750 - val_accuracy: 0.9797
# test model
# [<tf.Variable 'dense_27/kernel:0' shape=(2, 20) dtype=float32, numpy=
# array([[ 2.0657315e-12, -1.9045904e-01,  8.8417307e-02, -1.1138392e-06,
#          2.5214225e-11, -4.9385424e-03,  3.1810846e-02,  2.5567535e-01,
#          1.3887233e-02, -1.9864574e-01, -1.2593736e-03, -1.3323053e-35,
#         -2.8366441e-01,  1.5402134e-35,  1.7038879e-01,  1.9377004e-02,
#          3.4342143e-03, -1.5922053e-05,  8.9690949e-10, -7.5255903e-36],
#        [-2.6233274e-13,  1.7531849e-01,  6.3544624e-03, -3.5742909e-07,
#         -3.8377322e-15, -4.0087495e-03, -4.3115471e-02, -3.0881280e-01,
#         -8.8328579e-03, -2.1512519e-01, -1.0581512e-03,  1.4262159e-35,
#          2.1557599e-01,  9.2169404e-36,  1.4965533e-01, -2.1554751e-02,
#          1.5748437e-03, -4.8566337e-05, -1.4710813e-10,  3.9127475e-20]],
#       dtype=float32)>, <tf.Variable 'dense_27/bias:0' shape=(20,) dtype=float32, numpy=
# array([-9.0410035e-09,  3.0028941e-02,  2.1543412e-01,  7.8578751e-06,
#        -9.2368140e-07,  1.0899874e-01,  5.9865518e-03, -1.0212650e-02,
#         3.6442617e-01, -1.6366469e-02,  1.9447539e-02, -1.0597808e-05,
#         2.5425687e-02, -3.6009703e-02,  7.3270905e-03, -2.0658195e-03,
#         1.9451785e-01,  1.1312200e-03, -4.4168648e-03, -1.0709167e-08],
#       dtype=float32)>, <tf.Variable 'dense_28/kernel:0' shape=(20, 20) dtype=float32, numpy=
# array([[ 4.70195551e-13,  1.90606775e-12,  1.46646981e-35,
#         -1.99021247e-12, -1.57201389e-12,  2.62007072e-35,
#         -1.35922011e-11, -1.66283636e-11,  2.83141945e-13,
#         -8.89540611e-12, -5.99312050e-12, -3.36628967e-12,
#          2.42253682e-11,  3.53222449e-35, -7.33165872e-12,
#          5.37593572e-35, -8.08610037e-12,  8.92236209e-13,
#          6.81586038e-12,  2.98685854e-35],
#        [ 5.36718918e-03, -4.43899482e-02,  5.60044087e-02,
#         -3.37728022e-35,  1.27521679e-01,  2.89756000e-35,
#          5.96116763e-03,  1.30887359e-01, -1.13747619e-01,
#          7.36658573e-02, -3.00470160e-35,  1.51906630e-35,
#         -7.94422161e-03,  9.04713422e-02,  7.50368536e-02,
#         -5.68749166e-35, -7.62201706e-03,  3.69278336e-35,
#         -1.65460559e-35, -3.31196222e-35],
#        [ 1.69524423e-35,  6.00648718e-03, -2.00367626e-02,
#          2.95465700e-35, -1.85118765e-02,  3.12637187e-35,
#          1.67341214e-02, -4.44322601e-02,  1.66095644e-02,
#         -2.76562497e-02,  1.82729978e-02,  1.00695631e-02,
#         -2.76461206e-02, -1.03560649e-02, -1.08333454e-02,
#         -4.39274777e-35, -2.65166331e-02, -3.26654196e-36,
#         -2.86307261e-35,  3.84196209e-35],
#        [-6.37128778e-07,  3.11372555e-35, -1.27465287e-35,
#         -6.35673814e-07,  3.71714158e-35, -3.38542660e-35,
#         -6.29835881e-07,  1.47523872e-06,  1.06033730e-35,
#          8.14724558e-07, -7.72455223e-07, -2.79225674e-08,
#          1.22540382e-06, -2.27801722e-35,  8.91291222e-07,
#          1.74873310e-35,  1.30145418e-06,  8.11624261e-08,
#          1.13950932e-07,  4.41929770e-35],
#        [-5.45255333e-25, -3.12173672e-19, -3.17285299e-24,
#          1.19218768e-35, -4.68998437e-24, -1.07769349e-35,
#         -2.29149203e-25,  1.81668119e-24, -8.29068900e-18,
#          1.86323764e-15, -2.57410232e-36,  4.68331787e-35,
#          2.63748223e-25, -3.09554245e-25,  1.39161182e-15,
#          7.64119039e-36,  1.75310086e-22,  3.21211924e-35,
#         -2.68064800e-35, -3.51138185e-35],
#        [ 1.49311545e-35, -5.61316977e-35, -9.47020657e-04,
#         -1.39633102e-35, -2.72228794e-35,  5.16129149e-35,
#          1.05815823e-03, -5.91480173e-04, -5.86013206e-35,
#         -8.69495270e-04,  6.63167797e-04,  1.75433769e-03,
#         -6.46287459e-04,  3.40405744e-35,  5.20432216e-35,
#         -2.03439645e-35,  1.75862806e-05, -1.55533400e-35,
#         -3.96841806e-36,  2.45544067e-35],
#        [-5.65978652e-03, -1.76749087e-03,  4.79531800e-03,
#         -3.30251013e-03,  5.32216672e-03,  4.36979722e-35,
#         -1.12947607e-02,  2.71142144e-02, -4.84009925e-03,
#          1.42344171e-02, -1.05132377e-02, -3.92848020e-03,
#          2.08275896e-02,  8.42989516e-36,  7.62441615e-03,
#         -5.36560138e-26,  2.29205824e-02,  9.48465895e-04,
#          1.13735104e-03, -1.10006455e-35],
#        [-3.83420438e-02, -2.58661583e-02,  5.65495454e-02,
#         -2.26832051e-02,  8.11344981e-02,  1.69176797e-35,
#         -8.10727626e-02,  2.35805497e-01, -7.18681663e-02,
#          1.28095835e-01, -7.44469911e-02, -3.12182177e-02,
#          1.49150997e-01,  3.12814787e-02,  7.66741633e-02,
#         -7.09045292e-36,  1.53653875e-01,  5.93095599e-03,
#          6.84654433e-03,  2.58729234e-35],
#        [ 4.59794374e-03,  2.97537702e-03,  1.79391343e-03,
#          2.52969426e-35, -1.54833496e-02,  5.79309330e-35,
#          5.10404538e-03, -1.87132193e-03,  1.26474425e-02,
#         -1.47346116e-03,  3.21823807e-35, -3.14835097e-35,
#         -6.27666712e-03, -9.68102016e-04, -6.94106985e-03,
#         -2.96352945e-35, -5.81178768e-03,  1.79017229e-35,
#          2.11498640e-35, -1.62235669e-35],
#        [ 3.53382193e-02,  3.11565436e-02, -3.50589938e-02,
#          2.35983469e-02, -1.01088062e-01,  2.25964524e-35,
#          4.40886840e-02, -1.63904607e-01,  8.90401453e-02,
#         -9.08503830e-02,  3.71804051e-02,  1.75202359e-02,
#         -7.69276321e-02, -4.91786003e-02, -9.14572552e-02,
#         -2.38831768e-35, -7.86991790e-02, -1.72994228e-03,
#         -2.87768035e-03,  1.21846935e-35],
#        [-5.45123767e-04, -4.46723382e-35, -4.89553844e-04,
#         -5.76947990e-04, -1.08645230e-35,  2.97096841e-35,
#          1.34178292e-04,  2.21815862e-05, -3.59125520e-35,
#         -1.10181740e-04,  5.99665400e-05,  1.69843217e-04,
#         -7.41091644e-05,  2.39391476e-35,  5.18360117e-04,
#         -2.44260781e-35,  4.94303131e-05,  4.03344224e-04,
#          4.89079102e-04, -3.21168604e-36],
#        [-4.35607241e-35, -5.72453179e-35,  2.95253416e-35,
#          3.40579327e-36,  2.21137263e-35, -3.11234170e-35,
#          2.11792112e-35,  2.19043270e-35, -2.01160173e-35,
#         -2.28680789e-37, -2.25369172e-35,  3.01559071e-35,
#         -9.84318892e-36, -1.54754032e-35, -3.44265102e-35,
#          2.87366899e-35, -3.75735778e-35, -2.55971500e-35,
#         -2.33601119e-35,  3.17741604e-35],
#        [-2.37454008e-02,  5.00389840e-03,  5.24172448e-02,
#         -2.53634788e-02, -4.85675223e-03, -4.38843610e-35,
#         -8.28761533e-02,  1.92781165e-01,  5.87705802e-03,
#          1.04099132e-01, -9.41241607e-02, -4.26457934e-02,
#          1.52745247e-01,  1.28222097e-35,  3.29778194e-02,
#         -3.05385741e-35,  1.57878608e-01,  6.93063857e-03,
#          9.38235130e-03, -2.97141181e-35],
#        [-4.39937944e-35, -1.76065822e-35, -2.48885617e-35,
#          4.90708165e-35,  2.49749645e-35,  2.73172317e-35,
#         -3.08289120e-35, -2.68236446e-35, -1.46784333e-35,
#         -3.43601906e-35,  3.08749130e-35, -1.65391366e-35,
#         -1.75609012e-35, -2.45361745e-35,  5.63649656e-35,
#         -2.01787840e-35,  4.51732894e-35,  3.88581038e-35,
#         -2.46745046e-35, -3.21594017e-35],
#        [ 2.20604353e-02,  3.01962290e-02, -2.66390890e-02,
#          1.35285761e-02, -9.20602903e-02, -4.39422833e-35,
#          2.28600893e-02, -1.26453161e-01,  8.11789781e-02,
#         -6.93606809e-02,  1.65796522e-02,  6.33217348e-03,
#         -4.20501009e-02, -4.88061793e-02, -7.29067326e-02,
#         -4.34628676e-35, -4.31084670e-02, -2.19512288e-03,
#         -2.81331688e-03,  2.70005571e-35],
#        [-1.87124463e-03, -1.08503620e-03,  4.28431621e-03,
#         -1.82067021e-03,  3.16687254e-03, -3.46464103e-35,
#         -5.06557338e-03,  1.50094805e-02, -3.01809236e-03,
#          8.44328012e-03, -5.88603271e-03, -2.02884851e-03,
#          8.29338096e-03,  2.15628790e-03,  4.55596624e-03,
#          2.00137650e-13,  9.66261420e-03,  4.00331453e-04,
#          5.67034003e-04,  3.60116253e-35],
#        [ 1.80757465e-03,  3.39864171e-03, -2.05743848e-03,
#         -1.06023112e-03, -5.04028052e-03, -2.37309465e-35,
#          3.52033717e-03, -6.84241811e-03,  4.67956997e-03,
#         -4.17221244e-03,  1.98806240e-03,  1.10994873e-03,
#         -5.45131881e-03,  1.01446016e-35, -2.61339708e-03,
#         -2.87329390e-35, -3.52030620e-03,  2.60251318e-03,
#          2.64915731e-03, -1.87602384e-35],
#        [-3.43711617e-05,  1.14445123e-35,  1.02122664e-35,
#         -3.60745071e-05, -1.39823259e-35,  5.78784246e-38,
#         -1.16909054e-04,  1.99752729e-04,  2.50592150e-35,
#          1.31973458e-04, -3.55906704e-05, -4.95423919e-05,
#          2.21744718e-04,  2.77166874e-35,  4.00150966e-05,
#          3.33317737e-35,  5.41746085e-05,  3.41655141e-06,
#          1.76722315e-05, -2.89037559e-35],
#        [-1.12890736e-21,  5.12030933e-35, -1.47711068e-35,
#         -3.94113394e-22,  1.83123983e-35,  1.51604103e-35,
#          3.91486139e-35, -1.87111667e-35, -5.40200093e-35,
#         -2.64516994e-35, -1.28325605e-18, -5.04269916e-20,
#          3.04581320e-35, -5.79251187e-35,  3.22617215e-19,
#          2.03588562e-35,  1.69954266e-18, -1.32448912e-35,
#         -1.61027114e-35,  1.05599234e-36],
#        [-3.79676152e-35,  3.13086320e-35,  3.71680494e-37,
#         -4.69401584e-35,  4.18305376e-35, -2.93979313e-35,
#         -3.21307789e-34, -2.71728893e-35, -2.27495035e-35,
#          1.67549988e-35, -2.95235824e-35, -4.04928130e-35,
#          5.21278537e-35,  1.66045780e-35, -4.34332564e-35,
#         -8.76806933e-36, -1.74739359e-35,  4.50654745e-35,
#         -1.56364023e-35,  5.68875096e-35]], dtype=float32)>, <tf.Variable 'dense_28/bias:0' shape=(20,) dtype=float32, numpy=
# array([ 0.12137698,  0.41158518,  0.03386993,  0.08990233,  0.10618266,
#        -0.03143503,  0.2509129 ,  0.10089976,  0.1448216 ,  0.05786045,
#         0.27753755,  0.21607712,  0.01542832,  0.04841308,  0.2030373 ,
#        -0.13683754,  0.01265571,  0.12796955,  0.11505219, -0.01946235],
#       dtype=float32)>, <tf.Variable 'dense_29/kernel:0' shape=(20, 1) dtype=float32, numpy=
# array([[ 1.2050908 ],
#        [ 0.94075054],
#        [-1.1527283 ],
#        [ 1.1694803 ],
#        [-2.8363733 ],
#        [-0.09737187],
#        [ 1.2586684 ],
#        [-2.9137309 ],
#        [ 2.5098782 ],
#        [-1.5900195 ],
#        [ 1.4104466 ],
#        [ 0.63034827],
#        [-2.3345003 ],
#        [-1.9938008 ],
#        [-1.6321329 ],
#        [ 0.26743543],
#        [-2.3792949 ],
#        [-0.21940602],
#        [-0.2755241 ],
#        [-0.44686788]], dtype=float32)>, <tf.Variable 'dense_29/bias:0' shape=(1,) dtype=float32, numpy=array([0.30419454], dtype=float32)>]
# test accuracy: 0.626

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

# Load your trained model
# Replace 'your_model_path' with the path to your saved model
# model = tf.keras.models.load_model('your_model_path')

# Create a meshgrid in the specified coordinate range
x_vals = np.linspace(-2, 2, 100)
y_vals = np.linspace(-2, 2, 100)
x_grid, y_grid = np.meshgrid(x_vals, y_vals)

# Flatten the meshgrid coordinates for input to the model
input_grid = np.column_stack((x_grid.flatten(), y_grid.flatten()))

# Get the model predictions for the input grid
predictions = model.predict(input_grid)

# Reshape the predictions to match the shape of the meshgrid
predictions = predictions.reshape(x_grid.shape)

# Plot the contours of the predictions
plt.contourf(x_grid, y_grid, predictions, cmap='viridis', levels=50)
plt.colorbar()

# Optionally, plot the data points or decision boundary of 0.5 (for binary classification)
# For data points:
# plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', marker='o', edgecolors='k', linewidth=0.5)
# For decision boundary:
# plt.contour(x_grid, y_grid, predictions, levels=[0.5], colors='r', linestyles='dashed')

plt.xlabel('First Coordinate')
plt.ylabel('Second Coordinate')
plt.title('Network Output on 2D Input Grid')
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step
